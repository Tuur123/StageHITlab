# %%
import pandas as pd

# %%
df = pd.read_csv('gaze_positions.csv')

# %%
df = df.drop_duplicates(subset = ["world_index"])
df.head()
# Out:
#     gaze_timestamp  world_index  confidence  norm_pos_x  norm_pos_y  \
# 0    680672.926358            0    0.967774    0.432057   -0.495067
# 18   680673.381209            3    0.355535    0.147194   -0.177892
# 23   680673.407977            4    0.421033    0.574174   -0.190269
# 28   680673.430930            5    0.539623    0.602760   -0.217925
# 33   680673.456367            6    0.564908    0.620941   -0.190583
#
#                           base_data  gaze_point_3d_x  gaze_point_3d_y  \
# 0   680672.924326-0 680672.928389-1        -3.277901        27.758966
# 18                  680673.381209-0      -212.335138       215.315971
# 23                  680673.407977-0        47.067176       212.538871
# 28                   680673.43093-0        66.337811       229.962880
# 33                  680673.456367-0        75.686864       215.390774
#
#     gaze_point_3d_z  eye_center0_3d_x  ...  eye_center0_3d_z  gaze_normal0_x  \
# 0         17.781030         20.254333  ...        -21.804195       -0.490296
# 18       240.345618         25.759973  ...       -192.089859       -0.476190
# 23       300.644151         25.759973  ...       -192.089859        0.042614
# 28       302.031230         25.759973  ...       -192.089859        0.081156
# 33       299.040376         25.759973  ...       -192.089859        0.099854
#
#     gaze_normal0_y  gaze_normal0_z  eye_center1_3d_x  eye_center1_3d_y  \
# 0         0.289402        0.822105        -39.903478         14.296059
# 18       -0.158874        0.864871               NaN               NaN
# 23       -0.164429        0.985468               NaN               NaN
# 28       -0.129581        0.988242               NaN               NaN
# 33       -0.158725        0.982260               NaN               NaN
#
#     eye_center1_3d_z  gaze_normal1_x  gaze_normal1_y  gaze_normal1_z
# 0         -21.283263        0.663319        0.236142        0.710102
# 18               NaN             NaN             NaN             NaN
# 23               NaN             NaN             NaN             NaN
# 28               NaN             NaN             NaN             NaN
# 33               NaN             NaN             NaN             NaN
#
# [5 rows x 21 columns]

# %%
df = df[['world_index', 'norm_pos_x', 'norm_pos_y']]
df.head(50)
# Out:
#      world_index  norm_pos_x  norm_pos_y
# 0              0    0.432057   -0.495067
# 18             3    0.147194   -0.177892
# 23             4    0.574174   -0.190269
# 28             5    0.602760   -0.217925
# 33             6    0.620941   -0.190583
# 42             7    0.606846   -0.190985
# 47             8    0.703939   -0.328431
# 56             9    0.562026   -0.209988
# 64            10    0.691730   -0.329599
# 71            11    0.692542   -0.327841
# 79            12    0.690560   -0.336060
# 87            13    0.681679   -0.359304
# 95            14    0.593897   -0.487781
# 103           15    0.579597   -0.480177
# 112           16    0.535748   -0.532721
# 120           17    0.558291   -0.216234
# 128           18    0.514878   -0.576482
# 137           19    0.507216   -0.604812
# 145           20    0.491634   -0.623753
# 152           21    0.493451   -0.626862
# 162           22    0.681976   -0.362995
# 168           23    0.624072   -0.422536
# 177           24    0.433385    0.042583
# 186           25    0.609811    0.147756
# 195           26    0.622234    0.090747
# 203           27    0.618868    0.088196
# 211           28    0.620261    0.085573
# 220           29    0.629070    0.104204
# 227           30    0.657781    0.202494
# 237           31    0.683392    0.190577
# 250           32    0.700545    0.204804
# 260           33    0.709734    0.193198
# 269           34    0.717935    0.184888
# 277           35    0.725542    0.189695
# 284           36    0.728262    0.186660
# 291           37    0.730703    0.188916
# 297           38    0.728120    0.173057
# 305           39    0.723405    0.172596
# 312           40    0.718765    0.167692
# 320           41    0.715937    0.169807
# 328           42    0.712250    0.167503
# 335           43    0.712189    0.166900
# 343           44    0.713477    0.166261
# 351           45    0.713190    0.175187
# 358           46    0.712479    0.190132
# 369           47    0.700608    0.242723
# 378           48    0.787885    0.160725
# 383           49    0.460250   -0.148370
# 389           50    0.563925   -0.023750
# 395           51    0.547429    0.292026
